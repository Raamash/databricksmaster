# %%
name = "Raam"
for _ in range(3):
    print(name[::-1])

# %%
# %sql
select "Raam"

# %% [markdown]
# # this is Raam - taking class on Databricks

# %%
# %fs 
ls user/hive/warehouse/

# %%
#spark + python = Pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
